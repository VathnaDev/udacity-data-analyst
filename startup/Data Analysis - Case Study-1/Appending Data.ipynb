# %%
import pandas as pd
# %matplotlib inline

df_white = pd.read_csv('winequality-white.csv',sep=";")
df_red = pd.read_csv('winequality-red.csv',sep=";")

df_red.rename(columns = {'total_sulfur-dioxide':'total_sulfur_dioxide'})

df_wine = df_red.append(df_white,sort=False)
df_wine.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  total_sulfur_dioxide
# 0      9.4        5                   NaN
# 1      9.8        5                   NaN
# 2      9.8        5                   NaN
# 3      9.8        6                   NaN
# 4      9.4        5                   NaN

# %%
df_wine.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3B77F5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3BA82278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3BA98588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3B7AFB00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3B7E00B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3B808630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3B82FBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3B861198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3B8611D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3B8B1C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3BAB3208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3BAD9780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3BB01CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3BB322B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3BB5B828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026B3BB7B898>]],
#       dtype=object)
